# %% [markdown]
# # Check python version

# %%
import sys
print("python version:")
print(sys.version)
# Out:
# python version:
# 3.6.12 | packaged by conda-forge | (default, Dec  9 2020, 00:36:02)
# [GCC 9.3.0]

# %% [markdown]
# # Available CASA data reduction tasks

# %%
import casatasks
help(casatasks)
# Out:
# Help on package casatasks:
#
# NAME
#     casatasks
#
# DESCRIPTION
#     ###########################################################################
#     ########################## generated by setup.py ##########################
#     ###########################################################################
#
# PACKAGE CONTENTS
#     accor
#     accum
#     applycal
#     asdmsummary
#     bandpass
#     blcal
#     calstat
#     clearcal
#     clearstat
#     concat
#     config
#     conjugatevis
#     cvel
#     cvel2
#     delmod
#     exportasdm
#     exportfits
#     exportuvfits
#     feather
#     fixplanets
#     fixvis
#     flagcmd
#     flagdata
#     flagmanager
#     fluxscale
#     fringefit
#     ft
#     gaincal
#     gencal
#     hanningsmooth
#     imcollapse
#     imcontsub
#     imdev
#     imfit
#     imhead
#     imhistory
#     immath
#     immoments
#     impbcor
#     importasap
#     importasdm
#     importatca
#     importfits
#     importfitsidi
# ...

# %% [markdown]
# # Download the measurement set from the CASA Guide if you don't have it already

# %%
# import os
print("downloading MeasurementSet from CASA guide First Look at Imaging...")
# os.system("wget https://bulk.cv.nrao.edu/almadata/public/working/sis14_twhya_calibrated_flagged.ms.tar")
# os.system("tar -xvf sis14_twhya_calibrated_flagged.ms.tar")

# %% [markdown]
# # list the observation summary in log file and print

# %%
from casatasks import listobs

rc = listobs(vis='sis14_twhya_calibrated_flagged.ms')

print(os.popen("cat casa-*.log").read())
# Out:
# 2021-01-30 02:57:37	INFO	::casa
# 2021-01-30 02:57:38	INFO	::casa	CASA Version 6.1.2.7
# 2021-01-30 02:57:38	INFO	::casa	Can't import casatelemetry module.
# 2021-01-30 03:02:25	INFO	listobs::::casa	##########################################
# 2021-01-30 03:02:25	INFO	listobs::::casa	##### Begin Task: listobs            #####
# 2021-01-30 03:02:25	INFO	listobs::::casa	listobs( vis='sis14_twhya_calibrated_flagged.ms', selectdata=True, spw='', field='', antenna='', uvrange='', timerange='', correlation='', scan='', intent='', feed='', array='', observation='', verbose=True, listfile='', listunfl=False, cachesize=50.0, overwrite=False )
# 2021-01-30 03:02:26	INFO	listobs::ms::summary	================================================================================
# 2021-01-30 03:02:26	INFO	listobs::ms::summary+	           MeasurementSet Name:  /home/jovyan/sis14_twhya_calibrated_flagged.ms      MS Version 2
# ...

# %% [markdown]
# # View ALMA array configuration positions

# %%
from casatasks import plotants

plotants(vis='sis14_twhya_calibrated_flagged.ms')
# Out:
# Number of points being plotted: 26
# /opt/conda/lib/python3.6/site-packages/casatasks/private/task_plotants.py:337: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax = fig.add_subplot(111)

# %% [markdown]
# #  Radio Interferometric Image Reconstruction using tclean()
# Note: Only non-interactive mode is supported (interactive=False) as the CASA Viewer is not compatible.

# %%
from casatasks import tclean

print("running tclean, may take a bit...")

tclean(vis='sis14_twhya_calibrated_flagged.ms', imagename='first_image',
       field='5', spw='', specmode='mfs', deconvolver='hogbom', nterms=1,
       gridder='standard', imsize=[250,250], cell=['0.1arcsec'],
       weighting='natural', threshold='0mJy', niter=5000, 
       interactive=False, savemodel='modelcolumn')

print("complete")
# Out:
# running tclean, may take a bit...
# complete

# %% [markdown]
# # View Images with astropy

# %%
import matplotlib.pyplot as plt
from astropy.io import fits
from casatasks import exportfits

filenames = ['first_image.image', 'first_image.mask', 'first_image.model', 
             'first_image.pb', 'first_image.psf', 'first_image.residual']

ff, aa = plt.subplots(2,3, figsize=(18,12))
for ii, name in enumerate(filenames):
  exportfits(imagename=name, fitsimage=name+'.fits', overwrite=True)
  xx,yy = int(ii/3),ii%3
  im = aa[xx,yy].imshow(fits.getdata(name+'.fits')[0,0,:,:])
  plt.colorbar(im, ax=aa[xx,yy])
  aa[xx,yy].set_title(name)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-3a3ff673e223> in <module>
#       1 import matplotlib.pyplot as plt
# ----> 2 from astropy.io import fits
#       3 from casatasks import exportfits
#       4
#       5 filenames = ['first_image.image', 'first_image.mask', 'first_image.model',
#
# ModuleNotFoundError: No module named 'astropy'

# %% [markdown]
# # View Images with CARTA
# Consider this very experimental, even a bit magical

# %%
import subprocess as sp
import socket
import signal
import time
import requests

FRONT_PORT = '39138'  # make something up
BACK_PORT = '41578'
HOST_IP = socket.gethostbyname(socket.gethostname()) 

print("downloading ngrok...")
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip -o ngrok-stable-linux-amd64.zip"

print("downloading CARTA...")
# !wget https://github.com/CARTAvis/carta-releases/releases/download/v1.1/CARTA-v1.1-remote.tar.gz
# !tar -xvf CARTA-v1.1-remote.tar.gz
# !rm CARTA-v1.1-remote/carta-backend/lib/libstdc++.so.6
# !rm -r sample_data

cp = sp.Popen('CARTA-v1.1-remote/carta --port='+BACK_PORT + ' --fport='+FRONT_PORT, shell=True, preexec_fn=os.setsid, stdin=sp.PIPE, stdout=sp.PIPE, stderr=sp.STDOUT)
gp1 = sp.Popen('./ngrok http ' + HOST_IP+':'+FRONT_PORT, shell=True, preexec_fn=os.setsid, stdin=sp.PIPE, stdout=sp.PIPE, stderr=sp.STDOUT)
gp2 = sp.Popen('./ngrok http ' + HOST_IP+':'+BACK_PORT, shell=True, preexec_fn=os.setsid, stdin=sp.PIPE, stdout=sp.PIPE, stderr=sp.STDOUT)

time.sleep(2) # give the processes time to start
fcon = requests.get('http://localhost:4040/api/tunnels').json()['tunnels']
bcon = requests.get('http://localhost:4041/api/tunnels').json()['tunnels']
furl = [fcon[ii]['public_url'] for ii in range(len(fcon)) if fcon[ii]['proto'] == 'https'][0]
burl = [bcon[ii]['public_url'] for ii in range(len(bcon)) if bcon[ii]['proto'] == 'https'][0]
print('click this -> ' + furl +'/?socketUrl=' + burl.replace('https','wss'))
# Out:
# downloading ngrok...
# --2021-01-15 19:57:32--  https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# Resolving bin.equinox.io (bin.equinox.io)... 52.3.118.132, 3.230.235.205, 3.228.103.136, ...
# Connecting to bin.equinox.io (bin.equinox.io)|52.3.118.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13773305 (13M) [application/octet-stream]
# Saving to: ‘ngrok-stable-linux-amd64.zip’
#
# ngrok-stable-linux- 100%[===================>]  13.13M  53.8MB/s    in 0.2s
#
# 2021-01-15 19:57:32 (53.8 MB/s) - ‘ngrok-stable-linux-amd64.zip’ saved [13773305/13773305]
#
# /bin/bash: -c: line 0: unexpected EOF while looking for matching `"'
# /bin/bash: -c: line 1: syntax error: unexpected end of file
# downloading CARTA...
# --2021-01-15 19:57:33--  https://github.com/CARTAvis/carta-releases/releases/download/v1.1/CARTA-v1.1-remote.tar.gz
# Resolving github.com (github.com)... 140.82.114.4
# ...

# %%
# turn it off
os.killpg(os.getpgid(gp1.pid), signal.SIGTERM)
os.killpg(os.getpgid(gp2.pid), signal.SIGTERM)
os.killpg(os.getpgid(cp.pid), signal.SIGTERM)
print("stopped CARTA and the secure tunnels")
